# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G08 = nx.read_edgelist(
    './data/p2p-Gnutella08.txt',
    comments='#',
    delimiter=None,
    create_using=nx.DiGraph,
    nodetype=None,
    data=True,
    edgetype=None,
    encoding='utf-8',
)

# Layout: increase repulsion a bit and scale coordinates up
k08 = 2.5 / (G08.number_of_nodes() ** 0.5)
pos08 = nx.spring_layout(G08, seed=42, iterations=250, k=k08, scale=8.0)

# %%
plt.figure(figsize=(14, 10), dpi=160)
ax = plt.gca()
ax.set_axis_off()

# Nodes: tiny + very transparent (reduces overplotting)
nx.draw_networkx_nodes(
    G08,
    pos08,
    node_size=6,
    node_color="#6baed6",
    alpha=0.25,
    linewidths=0,
)

# Edges: hairline + extremely transparent; arrowheads kept but tiny
nx.draw_networkx_edges(
    G08,
    pos08,
    arrows=True,
    arrowstyle="-|>",
    arrowsize=4,
    width=0.25,
    alpha=0.08,
    edge_color="black",
    connectionstyle="arc3,rad=0.05",
)

plt.tight_layout()

# %%
G04 = nx.read_edgelist(
    './data/p2p-Gnutella04.txt',
    comments='#',
    delimiter=None,
    create_using=nx.DiGraph,
    nodetype=None,
    data=True,
    edgetype=None,
    encoding='utf-8',
)

# Layout: increase repulsion a bit and scale coordinates up
k04 = 2.5 / (G04.number_of_nodes() ** 0.5)
pos04 = nx.spring_layout(G04, seed=42, iterations=250, k=k04, scale=8.0)

# %%
plt.figure(figsize=(14, 10), dpi=160)
ax = plt.gca()
ax.set_axis_off()

nx.draw_networkx_nodes(
    G04,
    pos04,
    node_size=6,
    node_color="#6baed6",
    alpha=0.25,
    linewidths=0,
)

nx.draw_networkx_edges(
    G04,
    pos04,
    arrows=True,
    arrowstyle="-|>",
    arrowsize=4,
    width=0.25,
    alpha=0.08,
    edge_color="black",
    connectionstyle="arc3,rad=0.05",
)

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 14
#       3 ax.set_axis_off()
#       5 nx.draw_networkx_nodes(
#       6     G04,
#       7     pos04,
#    (...)     11     linewidths=0,
#      12 )
# ---> 14 nx.draw_networkx_edges(
#      15     G04,
#      16     pos04,
#      17     arrows=True,
#      18     arrowstyle="-|>",
#      19     arrowsize=4,
#      20     width=0.25,
#      21     alpha=0.08,
#      22     edge_color="black",
#      23     connectionstyle="arc3,rad=0.05",
#      24 )
#      26 plt.tight_layout()
#
# File ~/school/cs144/.venv/lib/python3.11/site-packages/networkx/drawing/nx_pylab.py:2101, in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, connectionstyle, min_source_margin, min_target_margin, hide_ticks)
#    2099     for i in range(len(edgelist)):
#    2100         arrow = fancy_arrow_factory(i)
# -> 2101         ax.add_patch(arrow)
#    2102         edge_viz_obj.append(arrow)
#    2104 # update view after drawing
#
# File ~/school/cs144/.venv/lib/python3.11/site-packages/matplotlib/axes/_base.py:2492, in _AxesBase.add_patch(self, p)
#    2490 if p.get_clip_path() is None:
#    2491     p.set_clip_path(self.patch)
# -> 2492 self._update_patch_limits(p)
#    2493 self._children.append(p)
#    2494 p._remove_method = self._children.remove
#
# File ~/school/cs144/.venv/lib/python3.11/site-packages/matplotlib/axes/_base.py:2510, in _AxesBase._update_patch_limits(self, patch)
#    2507 if (isinstance(patch, mpatches.Rectangle) and
#    2508         ((not patch.get_width()) and (not patch.get_height()))):
#    2509     return
# -> 2510 p = patch.get_path()
#    2511 # Get all vertices on the path
#    2512 # Loop through each segment to get extrema for Bezier curve sections
#    2513 vertices = []
#
# File ~/school/cs144/.venv/lib/python3.11/site-packages/matplotlib/patches.py:4465, in FancyArrowPatch.get_path(self)
#    4462 """Return the path of the arrow in the data coordinates."""
#    4463 # The path is generated in display coordinates, then converted back to
#    4464 # data coordinates.
# -> 4465 _path, fillable = self._get_path_in_displaycoord()
#    4466 if np.iterable(fillable):
#    4467     _path = Path.make_compound_path(*_path)
#
# File ~/school/cs144/.venv/lib/python3.11/site-packages/matplotlib/patches.py:4478, in FancyArrowPatch._get_path_in_displaycoord(self)
#    4476     posB = self._convert_xy_units(self._posA_posB[1])
#    4477     (posA, posB) = self.get_transform().transform((posA, posB))
# -> 4478     _path = self.get_connectionstyle()(posA, posB,
#    4479                                        patchA=self.patchA,
#    4480                                        patchB=self.patchB,
#    4481                                        shrinkA=self.shrinkA * dpi_cor,
#    4482                                        shrinkB=self.shrinkB * dpi_cor
#    4483                                        )
#    4484 else:
#    4485     _path = self.get_transform().transform_path(self._path_original)
#
# File ~/school/cs144/.venv/lib/python3.11/site-packages/matplotlib/patches.py:2837, in ConnectionStyle._Base.__call__(self, posA, posB, shrinkA, shrinkB, patchA, patchB)
#    2831 path = self.connect(posA, posB)
#    2832 path = self._clip(
#    2833     path,
#    2834     self._in_patch(patchA) if patchA else None,
#    2835     self._in_patch(patchB) if patchB else None,
#    2836 )
# -> 2837 path = self._clip(
#    2838     path,
#    2839     inside_circle(*path.vertices[0], shrinkA) if shrinkA else None,
#    2840     inside_circle(*path.vertices[-1], shrinkB) if shrinkB else None
#    2841 )
#    2842 return path
#
# File ~/school/cs144/.venv/lib/python3.11/site-packages/matplotlib/patches.py:2820, in ConnectionStyle._Base._clip(self, path, in_start, in_stop)
#    2818 if in_stop:
#    2819     try:
# -> 2820         path, _ = split_path_inout(path, in_stop)
#    2821     except ValueError:
#    2822         pass
#
# File ~/school/cs144/.venv/lib/python3.11/site-packages/matplotlib/bezier.py:378, in split_path_inout(path, inside, tolerance, reorder_inout)
#     375     raise ValueError("The path does not intersect with the patch")
#     377 bp = bezier_path.reshape((-1, 2))
# --> 378 left, right = split_bezier_intersecting_with_closedpath(
#     379     bp, inside, tolerance)
#     380 if len(left) == 2:
#     381     codes_left = [Path.LINETO]
#
# File ~/school/cs144/.venv/lib/python3.11/site-packages/matplotlib/bezier.py:338, in split_bezier_intersecting_with_closedpath(bezier, inside_closedpath, tolerance)
#     316 def split_bezier_intersecting_with_closedpath(
#     317         bezier, inside_closedpath, tolerance=0.01):
#     318     """
#     319     Split a Bézier curve into two at the intersection with a closed path.
#     320
#    (...)    335         Lists of control points for the two Bézier segments.
#     336     """
# --> 338     bz = BezierSegment(bezier)
#     339     bezier_point_at_t = bz.point_at_t
#     341     t0, t1 = find_bezier_t_intersecting_with_closedpath(
#     342         bezier_point_at_t, inside_closedpath, tolerance=tolerance)
#
# KeyboardInterrupt:
